# %%
from bddutils import DataHandler
from pathlib import Path

# %%
! pwd
# Out:
# /home/dcashon/spr2019_ee596_project

# %%
init_path = Path('./data/bdd100k/')

# %%
my_handler = DataHandler(init_path)

# %%
my_handler.get_random(5)

# %%
label_dir = '/mnt/disks/gscratch/bdd100k_labels_images_val.json'
img_dir = Path('/mnt/disks/gscratch/val')

# %%
my_handler.bb_to_train(256,5000, img_dir, label_dir, save_dir='./4g/', pix_num=2000)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-4e37156c3b54> in <module>
# ----> 1 my_handler.bb_to_train(256,5000, img_dir, label_dir, save_dir='./4g/', pix_num=2000)
#
# ~/spr2019_ee596_project/bddutils.py in bb_to_train(self, size, batch_size, img_dir, label_dir, save_dir, pix_num)
#      76         # load in the JSON
#      77         reader = codecs.getreader('utf-8')
# ---> 78         json_labels = json.load(reader(label_dir))
#      79         # get image list
#      80         img_list = os.listdir(img_dir)
#
# /usr/lib/python3.5/json/__init__.py in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     263
#     264     """
# --> 265     return loads(fp.read(),
#     266         cls=cls, object_hook=object_hook,
#     267         parse_float=parse_float, parse_int=parse_int,
#
# ...

# %%
import numpy as np
test = np.load('train_img_3.npy')

# %%
import matplotlib.pyplot as plt
for i in range(0,8):
    plt.figure()
    plt.imshow(yolo[i])
