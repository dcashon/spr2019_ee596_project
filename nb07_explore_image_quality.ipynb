# %%
import numpy as np
from pathlib import Path
import os
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.array([1,2,3,4])

# %%
# Out:
# array([1, 2, 3, 4])

# %%
raw_data = Path('./p_data/raw')
jpg_data = Path('./data/bdd100k/images/100k/train')
jpg = os.listdir(jpg_data)

# %%
# test
t1 = np.load(raw_data / 'train_img_0.npy')

# %%
t1_labels = np.load(raw_data / 'train_labels_0')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-14-43471d23efc5> in <module>
# ----> 1 t1_labels = np.load(raw_data / 'train_labels_0')
#
# ~/.conda/envs/neural_nets/lib/python3.6/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     420         own_fid = False
#     421     else:
# --> 422         fid = open(os_fspath(file), "rb")
#     423         own_fid = True
#     424
#
# FileNotFoundError: [Errno 2] No such file or directory: 'p_data/raw/train_labels_0'

# %%
for i in range(20,40):
    plt.figure()
    plt.imshow(t1[i])

# %%
for i in range(10):
    plt.figure(figsize=(12,10))
    plt.imshow(plt.imread(jpg_data / jpg[i]))
