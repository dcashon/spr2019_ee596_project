# %%
import matplotlib.pyplot as plt
import numpy as np
from keras.models import load_model
import matplotlib.patches as patches
# Out:
# Using TensorFlow backend.

# %%
x = np.load(open('/mnt/disks/gscratch/bdd100k/train_img_pixnum2000_3.npy', 'rb'))
y = np.load(open('/mnt/disks/gscratch/bdd100k/train_bbox_pixnum2000_3.npy', 'rb'))

# %%
regressor = load_model('/mnt/disks/gscratch/regressor__redo_epoch2.h5')
# Out:
# WARNING:tensorflow:From /home/dcashon/neural_nets/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/dcashon/neural_nets/lib/python3.5/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.

# %%
y_hat = regressor.predict(x)

# %%
for i in range(30,40):
    fig, ax = plt.subplots()
    ax.imshow(x[i])
    x1 = y[i][0]
    y1 = y[i][1]
    dx = y[i][2]
    dy = y[i][3]
    print(x1, y1, x2, y2)
    ax.add_patch(patches.Rectangle((x1, y1), dx, dy, linewidth=1, edgecolor='r', facecolor='None'))
# Out:
# 42 0 0 0
# 0 39 0 0
# 0 36 0 0
# 0 40 0 0
# 0 33 0 0
# 0 27 0 0
# 0 16 0 0
# 20 0 0 0
# 72 0 0 0
# 68 0 0 0
