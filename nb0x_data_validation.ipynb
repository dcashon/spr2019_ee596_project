# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
data_path = Path('/mnt/disks/gscratch/train')

# %%
x1 = np.load(data_path / 'test_img_pixnum2000_0.npy')

# %%
y1 = np.load(data_path / 'test_label_pixnum2000_0.npy')

# %%
# Out:
# 6
